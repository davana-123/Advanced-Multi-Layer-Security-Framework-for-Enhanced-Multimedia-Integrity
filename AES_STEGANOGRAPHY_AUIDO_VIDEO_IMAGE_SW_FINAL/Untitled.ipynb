# %%
import tkinter as tk
from tkinter import *
import os
from PIL import Image,ImageTk
from tkinter.filedialog import askopenfilename
import shutil
import random
import sys
import cv2

win=Tk()
win.title("Video Stegnography")
win.configure(background="#b0f69f")
win.geometry("1400x650")
lmain = Label(win)
lmain.place(x=330, y=50)
lmainr = Label(win)
lmainr.place(x=1050, y=50)

def exitwindow():
    win.destroy()
def getval():
    secret_key=labeli.get()
    message=labelsm.get()
    print(message)
    print(secret_key)
def res():
    secret_key=""
    message=""
def choose_vid():
    # C:/Users/sagpa/Downloads/images is the location of the image which you want to test..... you can change it according to the image location you have  
    fileName = askopenfilename(initialdir='C:\\Users\\Romes\\OneDrive\\Desktop\\steg_ui_tkinter\\sample', title='Select image for analysis ',
                           filetypes=[('video files', '.mp4')])
    print(fileName)
    vs = cv2.VideoCapture(fileName)
    def video_stream():
        (grabbed, frame) = vs.read()
        frame=cv2.resize(frame,(350,380))
        frame = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
        img = Image.fromarray(frame)
        imgtk = ImageTk.PhotoImage(image=img)
        lmain.imgtk = imgtk
        lmain.configure(image=imgtk)
        lmain.after(1, video_stream)
    video_stream()
def inp():
    global labeli,labelsm
    labels=Label(win,text="secret \nmessage",bg="white",fg="black",font=("times",12,"bold"))
    labels.place(x=20,y=320)
    labelsm=Entry(win,text="",bg="white",fg="black",font=("times",12,"bold"))
    labelsm.place(x=110,y=320)
    labeli=Entry(win,text="",bg="white",fg="black",font=("times",12,"bold"),show="*")
    labeli.place(x=30,y=295)
    labelis=Button(win,text="submit",bg="#26b305",fg="black",command=getval)
    labelis.place(x=220,y=295)
def choose_vide():
    # C:/Users/sagpa/Downloads/images is the location of the image which you want to test..... you can change it according to the image location you have  
    fileName = askopenfilename(initialdir='C:\\Users\\Romes\\OneDrive\\Desktop\\steg_ui_tkinter\\sample', title='Select image for analysis ',
                           filetypes=[('video files', '.mp4')])
    print(fileName)
    vs = cv2.VideoCapture(fileName)
    def video_stream():
        (grabbed, frame) = vs.read()
        frame=cv2.resize(frame,(350,380))
        frame = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
        img = Image.fromarray(frame)
        imgtk = ImageTk.PhotoImage(image=img)
        lmainr.imgtk = imgtk
        lmainr.configure(image=imgtk)
        lmainr.after(1, video_stream)
    video_stream()
    
        

labelL=Label(win,text="",bg="#e6ab81",fg="black",width=40,height=26)
labelL.place(x=20,y=50)
labelL=Label(win,text="Embedding",bg="#e6ab81",fg="black",font=("times",14,"bold"))
labelL.place(x=150,y=55)
labelL=Label(win,text="Menu",bg="#e6ab81",fg="black",font=("times",14,"bold"))
labelL.place(x=25,y=55)
labelL1=Button(win,text="Browse i/p Vieo",bg="#b0f69f",fg="black",width=20,height=2,font=("times",14,"bold"),activebackground="red",command=choose_vid)
labelL1.place(x=40,y=140)
labelL1=Button(win,text="Enter Secret Key",bg="#b0f69f",fg="black",width=20,height=2,font=("times",14,"bold"),activebackground="red",command=inp)
labelL1.place(x=40,y=215)
labelL1=Button(win,text="Embedding",bg="#b0f69f",fg="black",width=20,height=2,font=("times",14,"bold"),activebackground="red")
labelL1.place(x=40,y=370)


labelR=Label(win,text="",bg="#e6ab81",fg="black",width=40,height=25)
labelR.place(x=700,y=50)
labelL=Label(win,text="Extraction",bg="#e6ab81",fg="black",font=("times",14,"bold"))
labelL.place(x=850,y=50)
labelR=Label(win,text="Menu",bg="#e6ab81",fg="black",font=("times",14,"bold"))
labelR.place(x=705,y=55)
labelR1=Button(win,text="Load Embedded video",bg="#b0f69f",fg="black",width=20,height=2,font=("times",14,"bold"),activebackground="red",command=choose_vide)
labelR1.place(x=720,y=100)
labelR1=Button(win,text="Extraction",bg="#b0f69f",fg="black",width=20,height=2,font=("times",14,"bold"),activebackground="red")
labelR1.place(x=720,y=175)
labelR1=Button(win,text="Reset",bg="#b0f69f",fg="black",width=20,height=2,font=("times",14,"bold"),activebackground="red",command=res)
labelR1.place(x=720,y=250)
labelR1=Button(win,text="Exit",bg="#b0f69f",fg="black",width=20,height=2,font=("times",14,"bold"),activebackground="red",command=exitwindow)
labelR1.place(x=720,y=325)


win.mainloop()
# Out:
# C:/Users/Romes/OneDrive/Desktop/steg_ui_tkinter/sample/sample_video.mp4
# Exception in Tkinter callback
# Traceback (most recent call last):
#   File "C:\Users\Romes\anaconda3\envs\csv\lib\tkinter\__init__.py", line 1892, in __call__
#     return self.func(*args)
#   File "C:\Users\Romes\anaconda3\envs\csv\lib\tkinter\__init__.py", line 814, in callit
#     func(*args)
#   File "C:\Users\Romes\AppData\Local\Temp\ipykernel_25916\2748135790.py", line 38, in video_stream
#     frame=cv2.resize(frame,(350,380))
# cv2.error: OpenCV(4.6.0) D:\a\opencv-python\opencv-python\opencv\modules\imgproc\src\resize.cpp:4052: error: (-215:Assertion failed) !ssize.empty() in function 'cv::resize'
# hi
# hello
